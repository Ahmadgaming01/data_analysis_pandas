# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Students_exams.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         1000 non-null   object
#  1   math score     1000 non-null   int64
#  2   reading score  1000 non-null   int64
#  3   writing score  1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
ypoints = df['math score']
plt.plot(ypoints)
plt.show()

# %%
ypoints = df['math score' ]
plt.plot(ypoints , marker = 'o')
plt.show()

# %%
ypoints = df['math score' ]
plt.plot(ypoints , marker = 'o' , ls = '-.')
plt.show()

# %%
ypoints = df['math score' ]
plt.plot(ypoints , marker = 'o' , ls = '-.' , color = 'red' , linewidth = '0.1')
plt.show()

# %%
df = pd.read_csv('cars.csv')
x =df.rename(
    columns = {'Name ':'name',
    'Malfunctions':'malfunctions',
    'age':'age',} , inplace= True

)
df['name'] = df['name'].str.lower()
print(df)


#x = df[]
#y = df[]
# Out:
#          name  malfunctions  age
# 0        adui            44    3
# 1    mercedes            15    5
# 2          vw            11   12
# 3      hyndai            14   15
# 4         kia            15    7
# 5        opel            10   11
# 6       dacia             8   21
# 7         nio             7   81
# 8        seat            81   88
# 9   landrover            74   77
# 10     renult            11   67
# 11      tesal            46   15

# %%
y1 = df['malfunctions']
y2 = df['age']
plt.plot(y1 , marker = 'o')
plt.plot(y2 , marker = 'o')
plt.show()

# %%
df = pd.read_csv('cars.csv')
x =df.rename(
    columns = {'Name ':'name',
    'Malfunctions':'malfunctions',
    'age':'age',} , inplace= True

)
df['name'] = df['name'].str.lower()
x= df['name']
y = df['malfunctions']

plt.xlabel('maschine')
plt.ylabel('malfunctions')

plt.bar(x,y)

plt.show()

# %%
plt.bar(x,y , color = 'red' , width = 0.1)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.barh(x,y , color = 'red' , height=  0.1)
# Out:
# <BarContainer object of 12 artists>
